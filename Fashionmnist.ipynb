# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR  
from sklearn.model_selection import ParameterGrid

# %%
# Memeriksa ketersediaan GPU
# Perangkat akan diatur ke GPU jika tersedia, atau menggunakan CPU jika GPU tidak tersedia.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Definisi arsitektur CNN
class CNN(nn.Module):
    def __init__(self, kernel_size, pooling_type):
        super(CNN, self).__init__()
        # Lapisan konvolusi pertama: menerima input dengan 1 kanal, menghasilkan 32 fitur, dengan padding yang disesuaikan.
        self.conv1 = nn.Conv2d(1, 32, kernel_size=kernel_size, padding=(kernel_size // 2))
        # Lapisan pooling pertama: menggunakan MaxPooling atau AveragePooling sesuai parameter.
        self.pool1 = nn.MaxPool2d(2) if pooling_type == 'max' else nn.AvgPool2d(2)
        # Lapisan konvolusi kedua: menerima 32 fitur, menghasilkan 64 fitur, dengan padding yang disesuaikan.
        self.conv2 = nn.Conv2d(32, 64, kernel_size=kernel_size, padding=(kernel_size // 2))
        # Lapisan pooling kedua: menggunakan MaxPooling atau AveragePooling sesuai parameter.
        self.pool2 = nn.MaxPool2d(2) if pooling_type == 'max' else nn.AvgPool2d(2)
        # Lapisan fully connected pertama: menghubungkan hasil konvolusi ke 128 unit.
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        # Lapisan fully connected kedua: menghasilkan output untuk 10 kelas.
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        # Proses data: Konvolusi pertama -> Aktivasi ReLU -> Pooling pertama.
        x = self.pool1(torch.relu(self.conv1(x)))
        # Proses data: Konvolusi kedua -> Aktivasi ReLU -> Pooling kedua.
        x = self.pool2(torch.relu(self.conv2(x)))
        # Mengubah dimensi tensor untuk input ke fully connected layer.
        x = x.view(-1, 64 * 7 * 7)
        # Proses data: Fully connected pertama -> Aktivasi ReLU.
        x = torch.relu(self.fc1(x))
        # Proses data: Fully connected kedua (Output logits).
        x = self.fc2(x)
        return x

# %%
# Definisi kelas Early Stopping
class EarlyStopping:
    def __init__(self, patience=5, stop_epochs=[]):
        # Parameter `patience` menentukan jumlah epoch tanpa peningkatan sebelum pelatihan dihentikan.
        self.patience = patience
        self.counter = 0  # Menghitung jumlah epoch tanpa peningkatan.
        self.best_loss = None  # Menyimpan nilai loss terbaik yang tercatat.
        self.early_stop = False  # Flag untuk menentukan apakah pelatihan harus dihentikan.
        self.stop_epochs = set(stop_epochs)  # Daftar epoch tertentu yang ditentukan untuk penghentian awal.

    def __call__(self, val_loss, current_epoch):
        # Jika epoch saat ini ada dalam daftar stop_epochs, pelatihan dihentikan langsung.
        if current_epoch in self.stop_epochs:
            self.early_stop = True
            return

        # Memperbarui nilai loss terbaik jika validasi loss saat ini lebih baik.
        if self.best_loss is None or val_loss < self.best_loss:
            self.best_loss = val_loss
            self.counter = 0  # Reset counter jika ada peningkatan.
        else:
            self.counter += 1  # Tambah counter jika tidak ada peningkatan.
            # Menghentikan pelatihan jika jumlah epoch tanpa peningkatan melebihi `patience`.
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# Hyperparameter 
param_grid = ParameterGrid({
    'kernel_size': [3, 5, 7],
    'pooling_type': ['max', 'avg'],
    'optimizer_type': ['SGD', 'RMSProp', 'Adam'],
    'epochs': [50, 100, 250, 350]
})

# %%
# Persiapan data
# Transformasi data mencakup konversi ke tensor dan normalisasi nilai ke rentang -1 hingga 1.
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])
# Memuat dataset FashionMNIST untuk data latih dan validasi.
train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
val_dataset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)
# DataLoader digunakan untuk memuat data dalam batch ukuran 64.
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)  # Data latih dengan shuffle.
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)     # Data validasi tanpa shuffle.

# Fungsi untuk melatih dan mengevaluasi model berdasarkan parameter konfigurasi.
def train_and_evaluate(params):
    # Membuat model CNN berdasarkan parameter kernel_size dan pooling_type.
    model = CNN(kernel_size=params['kernel_size'], pooling_type=params['pooling_type']).to(device)
    criterion = nn.CrossEntropyLoss()  # Fungsi loss untuk klasifikasi multi-kelas.

    # Menentukan jenis optimizer berdasarkan konfigurasi.
    if params['optimizer_type'] == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
    else:
        optimizer = optim.Adam(model.parameters(), lr=0.001)

    # Scheduler untuk menurunkan learning rate secara bertahap.
    scheduler = StepLR(optimizer, step_size=10, gamma=0.1)
    # Menggunakan mekanisme early stopping dengan kesabaran 5 epoch.
    early_stopper = EarlyStopping(patience=5, stop_epochs=[25, 38, 13])

    for epoch in range(params['epochs']):
        model.train()  # Mengaktifkan mode pelatihan untuk model.
        running_loss = 0.0  # Menyimpan total loss selama satu epoch pelatihan.

        for inputs, labels in train_loader:  # Iterasi data latih dalam batch.
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()  # Mengatur ulang gradien sebelum backward pass.
            outputs = model(inputs)  # Melakukan forward pass pada data.
            loss = criterion(outputs, labels)  # Menghitung nilai loss.
            loss.backward()  # Backpropagation untuk menghitung gradien.
            optimizer.step()  # Memperbarui parameter model.
            running_loss += loss.item()  # Menyimpan total loss.

        model.eval()  # Mengaktifkan mode evaluasi untuk model.
        val_loss = 0.0  # Menyimpan total validasi loss.
        with torch.no_grad():  # Menonaktifkan gradien untuk validasi.
            for inputs, labels in val_loader:  # Iterasi data validasi dalam batch.
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)  # Melakukan forward pass pada data validasi.
                loss = criterion(outputs, labels)  # Menghitung validasi loss.
                val_loss += loss.item()

        val_loss /= len(val_loader)  # Menghitung rata-rata validasi loss.
        scheduler.step()  # Memperbarui learning rate berdasarkan scheduler.
        # Menampilkan hasil epoch saat ini.
        print(f"Epoch {epoch + 1}/{params['epochs']}, Loss: {running_loss / len(train_loader):.4f}, Val Loss: {val_loss:.4f}")

        # Memeriksa kondisi early stopping berdasarkan validasi loss.
        early_stopper(val_loss, epoch + 1)
        if early_stopper.early_stop:
            print("Early stopping triggered.")
            break

# Iterasi berbagai kombinasi parameter dari grid untuk eksperimen.
for params in param_grid:
    print(f"Evaluating with params: {params}")
    train_and_evaluate(params)
# Out:
# Evaluating with params: {'epochs': 50, 'kernel_size': 3, 'optimizer_type': 'SGD', 'pooling_type': 'max'}
# Epoch 1/50, Loss: 0.5302, Val Loss: 0.3647
# Epoch 2/50, Loss: 0.3179, Val Loss: 0.3234
# Epoch 3/50, Loss: 0.2684, Val Loss: 0.3037
# Epoch 13/50, Loss: 0.1343, Val Loss: 0.2351
# Early stopping triggered.
# Evaluating with params: {'epochs': 50, 'kernel_size': 7, 'optimizer_type': 'RMSProp', 'pooling_type': 'max'}
# Epoch 1/50, Loss: 0.4240, Val Loss: 0.3444
# Epoch 2/50, Loss: 0.2759, Val Loss: 0.2858
# Epoch 3/50, Loss: 0.2311, Val Loss: 0.2552
# Epoch 4/50, Loss: 0.1964, Val Loss: 0.2498
# Epoch 5/50, Loss: 0.1695, Val Loss: 0.2442
# Epoch 6/50, Loss: 0.1461, Val Loss: 0.2508
# Epoch 7/50, Loss: 0.1268, Val Loss: 0.2804
# Epoch 8/50, Loss: 0.1055, Val Loss: 0.2905
# Epoch 9/50, Loss: 0.0891, Val Loss: 0.3087
# Epoch 10/50, Loss: 0.0787, Val Loss: 0.3304
# Early stopping triggered.
# Evaluating with params: {'epochs': 50, 'kernel_size': 7, 'optimizer_type': 'RMSProp', 'pooling_type': 'avg'}
# Epoch 1/50, Loss: 0.4672, Val Loss: 0.3663
# Epoch 2/50, Loss: 0.3096, Val Loss: 0.3198
# Epoch 3/50, Loss: 0.2596, Val Loss: 0.2845
# Epoch 4/50, Loss: 0.2297, Val Loss: 0.2678
# Epoch 5/50, Loss: 0.2054, Val Loss: 0.2697
# Epoch 6/50, Loss: 0.1839, Val Loss: 0.2460
# Epoch 7/50, Loss: 0.1645, Val Loss: 0.2516
# Epoch 8/50, Loss: 0.1455, Val Loss: 0.2454
# Epoch 9/50, Loss: 0.1286, Val Loss: 0.2806
# Epoch 10/50, Loss: 0.1122, Val Loss: 0.2750
# Epoch 11/50, Loss: 0.0669, Val Loss: 0.2679
# Epoch 12/50, Loss: 0.0554, Val Loss: 0.2791
# Epoch 13/50, Loss: 0.0503, Val Loss: 0.2884
# Early stopping triggered.
# Evaluating with params: {'epochs': 50, 'kernel_size': 7, 'optimizer_type': 'Adam', 'pooling_type': 'max'}
# Epoch 1/50, Loss: 0.4277, Val Loss: 0.3311
# Epoch 2/50, Loss: 0.2825, Val Loss: 0.2834
# Epoch 3/50, Loss: 0.2370, Val Loss: 0.2734
# Epoch 4/50, Loss: 0.2027, Val Loss: 0.2936
# Epoch 5/50, Loss: 0.1756, Val Loss: 0.2658
# Epoch 6/50, Loss: 0.1540, Val Loss: 0.2654
# Epoch 7/50, Loss: 0.1328, Val Loss: 0.2661
# Epoch 8/50, Loss: 0.1158, Val Loss: 0.2887
# Epoch 9/50, Loss: 0.1001, Val Loss: 0.2872
# Epoch 10/50, Loss: 0.0858, Val Loss: 0.3259
# Epoch 11/50, Loss: 0.0434, Val Loss: 0.3227
# Early stopping triggered.
# Evaluating with params: {'epochs': 50, 'kernel_size': 7, 'optimizer_type': 'Adam', 'pooling_type': 'avg'}
# Epoch 1/50, Loss: 0.4676, Val Loss: 0.3511
# Epoch 2/50, Loss: 0.3025, Val Loss: 0.3057
# Epoch 3/50, Loss: 0.2561, Val Loss: 0.2877
# Epoch 4/50, Loss: 0.2231, Val Loss: 0.2674
# Epoch 5/50, Loss: 0.1984, Val Loss: 0.2577
# Epoch 6/50, Loss: 0.1778, Val Loss: 0.2442
# Epoch 7/50, Loss: 0.1583, Val Loss: 0.2445
# Epoch 8/50, Loss: 0.1371, Val Loss: 0.2575
# Epoch 9/50, Loss: 0.1212, Val Loss: 0.2602
# Epoch 10/50, Loss: 0.1072, Val Loss: 0.3140
# Epoch 11/50, Loss: 0.0636, Val Loss: 0.2685
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 3, 'optimizer_type': 'SGD', 'pooling_type': 'max'}
# Epoch 1/100, Loss: 0.5323, Val Loss: 0.3806
# Epoch 2/100, Loss: 0.3153, Val Loss: 0.3227
# Epoch 3/100, Loss: 0.2628, Val Loss: 0.2923
# Epoch 4/100, Loss: 0.2347, Val Loss: 0.2668
# Epoch 5/100, Loss: 0.2099, Val Loss: 0.2839
# Epoch 6/100, Loss: 0.1903, Val Loss: 0.2470
# Epoch 7/100, Loss: 0.1727, Val Loss: 0.2408
# Epoch 8/100, Loss: 0.1577, Val Loss: 0.2371
# Epoch 9/100, Loss: 0.1418, Val Loss: 0.2474
# Epoch 10/100, Loss: 0.1298, Val Loss: 0.2559
# Epoch 11/100, Loss: 0.0879, Val Loss: 0.2275
# Epoch 12/100, Loss: 0.0804, Val Loss: 0.2294
# Epoch 13/100, Loss: 0.0772, Val Loss: 0.2327
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 3, 'optimizer_type': 'SGD', 'pooling_type': 'avg'}
# Epoch 1/100, Loss: 0.6390, Val Loss: 0.4462
# Epoch 2/100, Loss: 0.3798, Val Loss: 0.3657
# Epoch 3/100, Loss: 0.3234, Val Loss: 0.3519
# Epoch 4/100, Loss: 0.2935, Val Loss: 0.2947
# Epoch 5/100, Loss: 0.2715, Val Loss: 0.3048
# Epoch 6/100, Loss: 0.2519, Val Loss: 0.2836
# Epoch 7/100, Loss: 0.2393, Val Loss: 0.2596
# Epoch 8/100, Loss: 0.2262, Val Loss: 0.2605
# Epoch 9/100, Loss: 0.2143, Val Loss: 0.2550
# Epoch 10/100, Loss: 0.2019, Val Loss: 0.2534
# Epoch 11/100, Loss: 0.1697, Val Loss: 0.2302
# Epoch 12/100, Loss: 0.1650, Val Loss: 0.2303
# Epoch 13/100, Loss: 0.1631, Val Loss: 0.2294
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 3, 'optimizer_type': 'RMSProp', 'pooling_type': 'max'}
# Epoch 1/100, Loss: 0.4345, Val Loss: 0.3347
# Epoch 2/100, Loss: 0.2786, Val Loss: 0.2974
# Epoch 3/100, Loss: 0.2334, Val Loss: 0.2558
# Epoch 4/100, Loss: 0.1995, Val Loss: 0.2444
# Epoch 5/100, Loss: 0.1738, Val Loss: 0.2375
# Epoch 6/100, Loss: 0.1516, Val Loss: 0.2390
# Epoch 7/100, Loss: 0.1318, Val Loss: 0.2699
# Epoch 8/100, Loss: 0.1137, Val Loss: 0.2508
# Epoch 9/100, Loss: 0.0979, Val Loss: 0.2558
# Epoch 10/100, Loss: 0.0819, Val Loss: 0.2831
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 3, 'optimizer_type': 'RMSProp', 'pooling_type': 'avg'}
# Epoch 1/100, Loss: 0.4881, Val Loss: 0.3671
# Epoch 2/100, Loss: 0.3198, Val Loss: 0.3150
# Epoch 3/100, Loss: 0.2703, Val Loss: 0.2878
# Epoch 4/100, Loss: 0.2429, Val Loss: 0.2742
# Epoch 5/100, Loss: 0.2184, Val Loss: 0.2427
# Epoch 6/100, Loss: 0.1986, Val Loss: 0.2576
# Epoch 7/100, Loss: 0.1818, Val Loss: 0.2673
# Epoch 8/100, Loss: 0.1672, Val Loss: 0.2290
# Epoch 9/100, Loss: 0.1524, Val Loss: 0.2325
# Epoch 10/100, Loss: 0.1371, Val Loss: 0.2277
# Epoch 11/100, Loss: 0.0984, Val Loss: 0.2233
# Epoch 12/100, Loss: 0.0911, Val Loss: 0.2273
# Epoch 13/100, Loss: 0.0869, Val Loss: 0.2292
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 3, 'optimizer_type': 'Adam', 'pooling_type': 'max'}
# Epoch 1/100, Loss: 0.4210, Val Loss: 0.3096
# Epoch 2/100, Loss: 0.2753, Val Loss: 0.2694
# Epoch 3/100, Loss: 0.2302, Val Loss: 0.2665
# Epoch 4/100, Loss: 0.1989, Val Loss: 0.2374
# Epoch 5/100, Loss: 0.1738, Val Loss: 0.2374
# Epoch 6/100, Loss: 0.1504, Val Loss: 0.2374
# Epoch 7/100, Loss: 0.1316, Val Loss: 0.2355
# Epoch 8/100, Loss: 0.1103, Val Loss: 0.2478
# Epoch 9/100, Loss: 0.0965, Val Loss: 0.2490
# Epoch 10/100, Loss: 0.0816, Val Loss: 0.2754
# Epoch 11/100, Loss: 0.0410, Val Loss: 0.2751
# Epoch 12/100, Loss: 0.0323, Val Loss: 0.2849
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 3, 'optimizer_type': 'Adam', 'pooling_type': 'avg'}
# Epoch 1/100, Loss: 0.4840, Val Loss: 0.3618
# Epoch 2/100, Loss: 0.3124, Val Loss: 0.3024
# Epoch 3/100, Loss: 0.2632, Val Loss: 0.2769
# Epoch 4/100, Loss: 0.2313, Val Loss: 0.2725
# Epoch 5/100, Loss: 0.2088, Val Loss: 0.2636
# Epoch 6/100, Loss: 0.1898, Val Loss: 0.2292
# Epoch 7/100, Loss: 0.1733, Val Loss: 0.2207
# Epoch 8/100, Loss: 0.1566, Val Loss: 0.2203
# Epoch 9/100, Loss: 0.1414, Val Loss: 0.2497
# Epoch 10/100, Loss: 0.1298, Val Loss: 0.2207
# Epoch 11/100, Loss: 0.0909, Val Loss: 0.2134
# Epoch 12/100, Loss: 0.0830, Val Loss: 0.2146
# Epoch 13/100, Loss: 0.0790, Val Loss: 0.2204
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 5, 'optimizer_type': 'SGD', 'pooling_type': 'max'}
# Epoch 1/100, Loss: 0.5289, Val Loss: 0.3908
# Epoch 2/100, Loss: 0.3144, Val Loss: 0.3173
# Epoch 3/100, Loss: 0.2640, Val Loss: 0.2952
# Epoch 4/100, Loss: 0.2307, Val Loss: 0.2672
# Epoch 5/100, Loss: 0.2056, Val Loss: 0.2539
# Epoch 6/100, Loss: 0.1861, Val Loss: 0.2472
# Epoch 7/100, Loss: 0.1691, Val Loss: 0.2365
# Epoch 8/100, Loss: 0.1514, Val Loss: 0.2476
# Epoch 9/100, Loss: 0.1336, Val Loss: 0.2570
# Epoch 10/100, Loss: 0.1208, Val Loss: 0.2374
# Epoch 11/100, Loss: 0.0756, Val Loss: 0.2306
# Epoch 12/100, Loss: 0.0670, Val Loss: 0.2375
# Epoch 13/100, Loss: 0.0626, Val Loss: 0.2431
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 5, 'optimizer_type': 'SGD', 'pooling_type': 'avg'}
# Epoch 1/100, Loss: 0.6178, Val Loss: 0.4319
# Epoch 2/100, Loss: 0.3756, Val Loss: 0.3526
# Epoch 3/100, Loss: 0.3210, Val Loss: 0.3343
# Epoch 4/100, Loss: 0.2864, Val Loss: 0.2967
# Epoch 5/100, Loss: 0.2620, Val Loss: 0.2880
# Epoch 6/100, Loss: 0.2418, Val Loss: 0.2772
# Epoch 7/100, Loss: 0.2256, Val Loss: 0.2557
# Epoch 8/100, Loss: 0.2131, Val Loss: 0.2528
# Epoch 9/100, Loss: 0.1991, Val Loss: 0.2474
# Epoch 10/100, Loss: 0.1892, Val Loss: 0.2384
# Epoch 11/100, Loss: 0.1548, Val Loss: 0.2219
# Epoch 12/100, Loss: 0.1483, Val Loss: 0.2219
# Epoch 13/100, Loss: 0.1453, Val Loss: 0.2227
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 5, 'optimizer_type': 'RMSProp', 'pooling_type': 'max'}
# Epoch 1/100, Loss: 0.4311, Val Loss: 0.3229
# Epoch 2/100, Loss: 0.2740, Val Loss: 0.2890
# Epoch 3/100, Loss: 0.2294, Val Loss: 0.2494
# Epoch 4/100, Loss: 0.1959, Val Loss: 0.2376
# Epoch 5/100, Loss: 0.1694, Val Loss: 0.2644
# Epoch 6/100, Loss: 0.1464, Val Loss: 0.2513
# Epoch 7/100, Loss: 0.1229, Val Loss: 0.2585
# Epoch 8/100, Loss: 0.1062, Val Loss: 0.2790
# Epoch 9/100, Loss: 0.0886, Val Loss: 0.2918
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 5, 'optimizer_type': 'RMSProp', 'pooling_type': 'avg'}
# Epoch 1/100, Loss: 0.4741, Val Loss: 0.3705
# Epoch 2/100, Loss: 0.3068, Val Loss: 0.3033
# Epoch 3/100, Loss: 0.2604, Val Loss: 0.2878
# Epoch 4/100, Loss: 0.2308, Val Loss: 0.2562
# Epoch 5/100, Loss: 0.2042, Val Loss: 0.2479
# Epoch 6/100, Loss: 0.1846, Val Loss: 0.2503
# Epoch 7/100, Loss: 0.1666, Val Loss: 0.2362
# Epoch 8/100, Loss: 0.1478, Val Loss: 0.2303
# Epoch 9/100, Loss: 0.1315, Val Loss: 0.2405
# Epoch 10/100, Loss: 0.1183, Val Loss: 0.2480
# Epoch 11/100, Loss: 0.0737, Val Loss: 0.2391
# Epoch 12/100, Loss: 0.0651, Val Loss: 0.2414
# Epoch 13/100, Loss: 0.0601, Val Loss: 0.2487
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 5, 'optimizer_type': 'Adam', 'pooling_type': 'max'}
# Epoch 1/100, Loss: 0.4231, Val Loss: 0.3234
# Epoch 2/100, Loss: 0.2663, Val Loss: 0.2898
# Epoch 3/100, Loss: 0.2234, Val Loss: 0.2599
# Epoch 4/100, Loss: 0.1923, Val Loss: 0.2447
# Epoch 5/100, Loss: 0.1661, Val Loss: 0.2507
# Epoch 6/100, Loss: 0.1425, Val Loss: 0.2476
# Epoch 7/100, Loss: 0.1226, Val Loss: 0.2675
# Epoch 8/100, Loss: 0.1064, Val Loss: 0.2762
# Epoch 9/100, Loss: 0.0887, Val Loss: 0.2875
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 5, 'optimizer_type': 'Adam', 'pooling_type': 'avg'}
# Epoch 1/100, Loss: 0.4616, Val Loss: 0.3460
# Epoch 2/100, Loss: 0.3000, Val Loss: 0.3051
# Epoch 3/100, Loss: 0.2528, Val Loss: 0.2656
# Epoch 4/100, Loss: 0.2223, Val Loss: 0.2511
# Epoch 5/100, Loss: 0.1992, Val Loss: 0.2546
# Epoch 6/100, Loss: 0.1803, Val Loss: 0.2311
# Epoch 7/100, Loss: 0.1592, Val Loss: 0.2398
# Epoch 8/100, Loss: 0.1418, Val Loss: 0.2473
# Epoch 9/100, Loss: 0.1260, Val Loss: 0.2452
# Epoch 10/100, Loss: 0.1096, Val Loss: 0.2724
# Epoch 11/100, Loss: 0.0672, Val Loss: 0.2568
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 7, 'optimizer_type': 'SGD', 'pooling_type': 'max'}
# Epoch 1/100, Loss: 0.5181, Val Loss: 0.3613
# Epoch 2/100, Loss: 0.3027, Val Loss: 0.3158
# Epoch 3/100, Loss: 0.2588, Val Loss: 0.2835
# Epoch 4/100, Loss: 0.2281, Val Loss: 0.2634
# Epoch 5/100, Loss: 0.2066, Val Loss: 0.2737
# Epoch 6/100, Loss: 0.1837, Val Loss: 0.2437
# Epoch 7/100, Loss: 0.1663, Val Loss: 0.2491
# Epoch 8/100, Loss: 0.1486, Val Loss: 0.2484
# Epoch 9/100, Loss: 0.1317, Val Loss: 0.2660
# Epoch 10/100, Loss: 0.1161, Val Loss: 0.2586
# Epoch 11/100, Loss: 0.0692, Val Loss: 0.2550
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 7, 'optimizer_type': 'SGD', 'pooling_type': 'avg'}
# Epoch 1/100, Loss: 0.6175, Val Loss: 0.4335
# Epoch 2/100, Loss: 0.3684, Val Loss: 0.3493
# Epoch 3/100, Loss: 0.3143, Val Loss: 0.3298
# Epoch 4/100, Loss: 0.2835, Val Loss: 0.3221
# Epoch 5/100, Loss: 0.2600, Val Loss: 0.3241
# Epoch 6/100, Loss: 0.2418, Val Loss: 0.2876
# Epoch 7/100, Loss: 0.2233, Val Loss: 0.2692
# Epoch 8/100, Loss: 0.2122, Val Loss: 0.2735
# Epoch 9/100, Loss: 0.1990, Val Loss: 0.2613
# Epoch 10/100, Loss: 0.1876, Val Loss: 0.2694
# Epoch 11/100, Loss: 0.1502, Val Loss: 0.2378
# Epoch 12/100, Loss: 0.1416, Val Loss: 0.2417
# Epoch 13/100, Loss: 0.1381, Val Loss: 0.2415
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 7, 'optimizer_type': 'RMSProp', 'pooling_type': 'max'}
# Epoch 1/100, Loss: 0.4232, Val Loss: 0.3618
# Epoch 2/100, Loss: 0.2810, Val Loss: 0.2882
# Epoch 3/100, Loss: 0.2331, Val Loss: 0.2633
# Epoch 4/100, Loss: 0.2014, Val Loss: 0.2544
# Epoch 5/100, Loss: 0.1726, Val Loss: 0.2524
# Epoch 6/100, Loss: 0.1487, Val Loss: 0.2707
# Epoch 7/100, Loss: 0.1264, Val Loss: 0.2923
# Epoch 8/100, Loss: 0.1086, Val Loss: 0.2753
# Epoch 9/100, Loss: 0.0935, Val Loss: 0.2963
# Epoch 10/100, Loss: 0.0793, Val Loss: 0.3174
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 7, 'optimizer_type': 'RMSProp', 'pooling_type': 'avg'}
# Epoch 1/100, Loss: 0.4672, Val Loss: 0.3658
# Epoch 2/100, Loss: 0.3050, Val Loss: 0.2967
# Epoch 3/100, Loss: 0.2599, Val Loss: 0.2730
# Epoch 4/100, Loss: 0.2271, Val Loss: 0.2657
# Epoch 5/100, Loss: 0.2041, Val Loss: 0.2609
# Epoch 6/100, Loss: 0.1822, Val Loss: 0.2486
# Epoch 7/100, Loss: 0.1626, Val Loss: 0.2583
# Epoch 8/100, Loss: 0.1443, Val Loss: 0.2473
# Epoch 9/100, Loss: 0.1272, Val Loss: 0.2577
# Epoch 10/100, Loss: 0.1102, Val Loss: 0.2582
# Epoch 11/100, Loss: 0.0660, Val Loss: 0.2677
# Epoch 12/100, Loss: 0.0551, Val Loss: 0.2732
# Epoch 13/100, Loss: 0.0497, Val Loss: 0.2878
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 7, 'optimizer_type': 'Adam', 'pooling_type': 'max'}
# Epoch 1/100, Loss: 0.4300, Val Loss: 0.3696
# Epoch 2/100, Loss: 0.2829, Val Loss: 0.2895
# Epoch 3/100, Loss: 0.2358, Val Loss: 0.2628
# Epoch 4/100, Loss: 0.2043, Val Loss: 0.2738
# Epoch 5/100, Loss: 0.1775, Val Loss: 0.2498
# Epoch 6/100, Loss: 0.1537, Val Loss: 0.2615
# Epoch 7/100, Loss: 0.1340, Val Loss: 0.2646
# Epoch 8/100, Loss: 0.1152, Val Loss: 0.2698
# Epoch 9/100, Loss: 0.1002, Val Loss: 0.3085
# Epoch 10/100, Loss: 0.0829, Val Loss: 0.3333
# Early stopping triggered.
# Evaluating with params: {'epochs': 100, 'kernel_size': 7, 'optimizer_type': 'Adam', 'pooling_type': 'avg'}
# Epoch 1/100, Loss: 0.4739, Val Loss: 0.3796
# Epoch 2/100, Loss: 0.3106, Val Loss: 0.3166
# Epoch 3/100, Loss: 0.2637, Val Loss: 0.2749
# Epoch 4/100, Loss: 0.2315, Val Loss: 0.2639
# Epoch 5/100, Loss: 0.2065, Val Loss: 0.2593
# Epoch 6/100, Loss: 0.1864, Val Loss: 0.2512
# Epoch 7/100, Loss: 0.1644, Val Loss: 0.2582
# Epoch 8/100, Loss: 0.1488, Val Loss: 0.2466
# Epoch 9/100, Loss: 0.1309, Val Loss: 0.2753
# Epoch 10/100, Loss: 0.1183, Val Loss: 0.2608
# Epoch 11/100, Loss: 0.0717, Val Loss: 0.2618
# Epoch 12/100, Loss: 0.0599, Val Loss: 0.2719
# Epoch 13/100, Loss: 0.0543, Val Loss: 0.2869
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 3, 'optimizer_type': 'SGD', 'pooling_type': 'max'}
# Epoch 1/250, Loss: 0.5355, Val Loss: 0.3969
# Epoch 2/250, Loss: 0.3205, Val Loss: 0.3078
# Epoch 3/250, Loss: 0.2730, Val Loss: 0.2832
# Epoch 4/250, Loss: 0.2426, Val Loss: 0.2876
# Epoch 5/250, Loss: 0.2184, Val Loss: 0.2634
# Epoch 6/250, Loss: 0.1994, Val Loss: 0.2469
# Epoch 7/250, Loss: 0.1844, Val Loss: 0.2460
# Epoch 8/250, Loss: 0.1657, Val Loss: 0.2607
# Epoch 9/250, Loss: 0.1523, Val Loss: 0.2366
# Epoch 10/250, Loss: 0.1400, Val Loss: 0.2419
# Epoch 11/250, Loss: 0.0984, Val Loss: 0.2248
# Epoch 12/250, Loss: 0.0905, Val Loss: 0.2291
# Epoch 13/250, Loss: 0.0868, Val Loss: 0.2287
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 3, 'optimizer_type': 'SGD', 'pooling_type': 'avg'}
# Epoch 1/250, Loss: 0.6540, Val Loss: 0.4800
# Epoch 2/250, Loss: 0.3927, Val Loss: 0.3654
# Epoch 3/250, Loss: 0.3341, Val Loss: 0.3452
# Epoch 4/250, Loss: 0.2987, Val Loss: 0.3030
# Epoch 5/250, Loss: 0.2770, Val Loss: 0.3328
# Epoch 6/250, Loss: 0.2571, Val Loss: 0.2801
# Epoch 7/250, Loss: 0.2387, Val Loss: 0.2694
# Epoch 8/250, Loss: 0.2252, Val Loss: 0.2718
# Epoch 9/250, Loss: 0.2130, Val Loss: 0.2620
# Epoch 10/250, Loss: 0.2040, Val Loss: 0.2452
# Epoch 11/250, Loss: 0.1709, Val Loss: 0.2317
# Epoch 12/250, Loss: 0.1657, Val Loss: 0.2326
# Epoch 13/250, Loss: 0.1634, Val Loss: 0.2330
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 3, 'optimizer_type': 'RMSProp', 'pooling_type': 'max'}
# Epoch 1/250, Loss: 0.4285, Val Loss: 0.3419
# Epoch 2/250, Loss: 0.2748, Val Loss: 0.2797
# Epoch 3/250, Loss: 0.2263, Val Loss: 0.2676
# Epoch 4/250, Loss: 0.1965, Val Loss: 0.2628
# Epoch 5/250, Loss: 0.1719, Val Loss: 0.2286
# Epoch 6/250, Loss: 0.1456, Val Loss: 0.2322
# Epoch 7/250, Loss: 0.1250, Val Loss: 0.2384
# Epoch 8/250, Loss: 0.1065, Val Loss: 0.2515
# Epoch 9/250, Loss: 0.0898, Val Loss: 0.2502
# Epoch 10/250, Loss: 0.0758, Val Loss: 0.3046
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 3, 'optimizer_type': 'RMSProp', 'pooling_type': 'avg'}
# Epoch 1/250, Loss: 0.4828, Val Loss: 0.3688
# Epoch 2/250, Loss: 0.3150, Val Loss: 0.3086
# Epoch 3/250, Loss: 0.2700, Val Loss: 0.2898
# Epoch 4/250, Loss: 0.2387, Val Loss: 0.2636
# Epoch 5/250, Loss: 0.2162, Val Loss: 0.2512
# Epoch 6/250, Loss: 0.1968, Val Loss: 0.2371
# Epoch 7/250, Loss: 0.1795, Val Loss: 0.2260
# Epoch 8/250, Loss: 0.1642, Val Loss: 0.2303
# Epoch 9/250, Loss: 0.1509, Val Loss: 0.2257
# Epoch 10/250, Loss: 0.1385, Val Loss: 0.2260
# Epoch 11/250, Loss: 0.1017, Val Loss: 0.2118
# Epoch 12/250, Loss: 0.0938, Val Loss: 0.2150
# Epoch 13/250, Loss: 0.0902, Val Loss: 0.2152
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 3, 'optimizer_type': 'Adam', 'pooling_type': 'max'}
# Epoch 1/250, Loss: 0.4299, Val Loss: 0.3174
# Epoch 2/250, Loss: 0.2784, Val Loss: 0.3018
# Epoch 3/250, Loss: 0.2318, Val Loss: 0.2521
# Epoch 4/250, Loss: 0.1988, Val Loss: 0.2522
# Epoch 5/250, Loss: 0.1717, Val Loss: 0.2364
# Epoch 6/250, Loss: 0.1488, Val Loss: 0.2415
# Epoch 7/250, Loss: 0.1278, Val Loss: 0.2686
# Epoch 8/250, Loss: 0.1082, Val Loss: 0.2495
# Epoch 9/250, Loss: 0.0895, Val Loss: 0.2687
# Epoch 10/250, Loss: 0.0767, Val Loss: 0.3066
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 3, 'optimizer_type': 'Adam', 'pooling_type': 'avg'}
# Epoch 1/250, Loss: 0.4870, Val Loss: 0.3702
# Epoch 2/250, Loss: 0.3145, Val Loss: 0.3088
# Epoch 3/250, Loss: 0.2680, Val Loss: 0.2873
# Epoch 4/250, Loss: 0.2368, Val Loss: 0.2729
# Epoch 5/250, Loss: 0.2126, Val Loss: 0.2462
# Epoch 6/250, Loss: 0.1926, Val Loss: 0.2326
# Epoch 7/250, Loss: 0.1774, Val Loss: 0.2253
# Epoch 8/250, Loss: 0.1629, Val Loss: 0.2404
# Epoch 9/250, Loss: 0.1508, Val Loss: 0.2281
# Epoch 10/250, Loss: 0.1369, Val Loss: 0.2289
# Epoch 11/250, Loss: 0.1009, Val Loss: 0.2137
# Epoch 12/250, Loss: 0.0930, Val Loss: 0.2170
# Epoch 13/250, Loss: 0.0892, Val Loss: 0.2183
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 5, 'optimizer_type': 'SGD', 'pooling_type': 'max'}
# Epoch 1/250, Loss: 0.5222, Val Loss: 0.3698
# Epoch 2/250, Loss: 0.3066, Val Loss: 0.3141
# Epoch 3/250, Loss: 0.2569, Val Loss: 0.2688
# Epoch 4/250, Loss: 0.2251, Val Loss: 0.2626
# Epoch 5/250, Loss: 0.2021, Val Loss: 0.2444
# Epoch 6/250, Loss: 0.1822, Val Loss: 0.2606
# Epoch 7/250, Loss: 0.1641, Val Loss: 0.2417
# Epoch 8/250, Loss: 0.1480, Val Loss: 0.2385
# Epoch 9/250, Loss: 0.1314, Val Loss: 0.2383
# Epoch 10/250, Loss: 0.1180, Val Loss: 0.2469
# Epoch 11/250, Loss: 0.0745, Val Loss: 0.2299
# Epoch 12/250, Loss: 0.0653, Val Loss: 0.2340
# Epoch 13/250, Loss: 0.0612, Val Loss: 0.2369
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 5, 'optimizer_type': 'SGD', 'pooling_type': 'avg'}
# Epoch 1/250, Loss: 0.6074, Val Loss: 0.4421
# Epoch 2/250, Loss: 0.3800, Val Loss: 0.3640
# Epoch 3/250, Loss: 0.3242, Val Loss: 0.3423
# Epoch 4/250, Loss: 0.2900, Val Loss: 0.3050
# Epoch 5/250, Loss: 0.2657, Val Loss: 0.3301
# Epoch 6/250, Loss: 0.2467, Val Loss: 0.2703
# Epoch 7/250, Loss: 0.2289, Val Loss: 0.2748
# Epoch 8/250, Loss: 0.2169, Val Loss: 0.2577
# Epoch 9/250, Loss: 0.2031, Val Loss: 0.2721
# Epoch 10/250, Loss: 0.1908, Val Loss: 0.2475
# Epoch 11/250, Loss: 0.1562, Val Loss: 0.2288
# Epoch 12/250, Loss: 0.1497, Val Loss: 0.2275
# Epoch 13/250, Loss: 0.1467, Val Loss: 0.2282
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 5, 'optimizer_type': 'RMSProp', 'pooling_type': 'max'}
# Epoch 1/250, Loss: 0.4189, Val Loss: 0.3054
# Epoch 2/250, Loss: 0.2663, Val Loss: 0.2750
# Epoch 3/250, Loss: 0.2202, Val Loss: 0.2421
# Epoch 4/250, Loss: 0.1859, Val Loss: 0.2320
# Epoch 5/250, Loss: 0.1592, Val Loss: 0.2390
# Epoch 6/250, Loss: 0.1352, Val Loss: 0.2456
# Epoch 7/250, Loss: 0.1132, Val Loss: 0.2588
# Epoch 8/250, Loss: 0.0936, Val Loss: 0.2697
# Epoch 9/250, Loss: 0.0767, Val Loss: 0.3182
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 5, 'optimizer_type': 'RMSProp', 'pooling_type': 'avg'}
# Epoch 1/250, Loss: 0.4581, Val Loss: 0.3524
# Epoch 2/250, Loss: 0.2964, Val Loss: 0.2983
# Epoch 3/250, Loss: 0.2517, Val Loss: 0.2674
# Epoch 4/250, Loss: 0.2217, Val Loss: 0.2565
# Epoch 5/250, Loss: 0.1981, Val Loss: 0.2509
# Epoch 6/250, Loss: 0.1771, Val Loss: 0.2385
# Epoch 7/250, Loss: 0.1566, Val Loss: 0.2492
# Epoch 8/250, Loss: 0.1405, Val Loss: 0.2480
# Epoch 9/250, Loss: 0.1241, Val Loss: 0.2440
# Epoch 10/250, Loss: 0.1075, Val Loss: 0.2729
# Epoch 11/250, Loss: 0.0655, Val Loss: 0.2529
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 5, 'optimizer_type': 'Adam', 'pooling_type': 'max'}
# Epoch 1/250, Loss: 0.4168, Val Loss: 0.3116
# Epoch 2/250, Loss: 0.2626, Val Loss: 0.2665
# Epoch 3/250, Loss: 0.2212, Val Loss: 0.2414
# Epoch 4/250, Loss: 0.1896, Val Loss: 0.2368
# Epoch 5/250, Loss: 0.1595, Val Loss: 0.2364
# Epoch 6/250, Loss: 0.1367, Val Loss: 0.2534
# Epoch 7/250, Loss: 0.1118, Val Loss: 0.2647
# Epoch 8/250, Loss: 0.0953, Val Loss: 0.2541
# Epoch 9/250, Loss: 0.0799, Val Loss: 0.2946
# Epoch 10/250, Loss: 0.0685, Val Loss: 0.3125
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 5, 'optimizer_type': 'Adam', 'pooling_type': 'avg'}
# Epoch 1/250, Loss: 0.4716, Val Loss: 0.3450
# Epoch 2/250, Loss: 0.3000, Val Loss: 0.3145
# Epoch 3/250, Loss: 0.2556, Val Loss: 0.2743
# Epoch 4/250, Loss: 0.2267, Val Loss: 0.2569
# Epoch 5/250, Loss: 0.2028, Val Loss: 0.2540
# Epoch 6/250, Loss: 0.1817, Val Loss: 0.2369
# Epoch 7/250, Loss: 0.1646, Val Loss: 0.2335
# Epoch 8/250, Loss: 0.1454, Val Loss: 0.2300
# Epoch 9/250, Loss: 0.1303, Val Loss: 0.2551
# Epoch 10/250, Loss: 0.1151, Val Loss: 0.2517
# Epoch 11/250, Loss: 0.0731, Val Loss: 0.2392
# Epoch 12/250, Loss: 0.0630, Val Loss: 0.2472
# Epoch 13/250, Loss: 0.0580, Val Loss: 0.2483
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 7, 'optimizer_type': 'SGD', 'pooling_type': 'max'}
# Epoch 1/250, Loss: 0.5243, Val Loss: 0.4094
# Epoch 2/250, Loss: 0.3102, Val Loss: 0.3187
# Epoch 3/250, Loss: 0.2614, Val Loss: 0.2803
# Epoch 4/250, Loss: 0.2326, Val Loss: 0.2680
# Epoch 5/250, Loss: 0.2086, Val Loss: 0.2547
# Epoch 6/250, Loss: 0.1880, Val Loss: 0.2608
# Epoch 7/250, Loss: 0.1683, Val Loss: 0.2485
# Epoch 8/250, Loss: 0.1524, Val Loss: 0.2538
# Epoch 9/250, Loss: 0.1354, Val Loss: 0.2624
# Epoch 10/250, Loss: 0.1204, Val Loss: 0.2579
# Epoch 11/250, Loss: 0.0751, Val Loss: 0.2488
# Epoch 12/250, Loss: 0.0631, Val Loss: 0.2555
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 7, 'optimizer_type': 'SGD', 'pooling_type': 'avg'}
# Epoch 1/250, Loss: 0.6012, Val Loss: 0.4463
# Epoch 2/250, Loss: 0.3642, Val Loss: 0.3720
# Epoch 3/250, Loss: 0.3090, Val Loss: 0.3369
# Epoch 4/250, Loss: 0.2820, Val Loss: 0.3044
# Epoch 5/250, Loss: 0.2564, Val Loss: 0.2877
# Epoch 6/250, Loss: 0.2393, Val Loss: 0.2945
# Epoch 7/250, Loss: 0.2240, Val Loss: 0.2674
# Epoch 8/250, Loss: 0.2089, Val Loss: 0.2563
# Epoch 9/250, Loss: 0.1974, Val Loss: 0.2621
# Epoch 10/250, Loss: 0.1831, Val Loss: 0.2501
# Epoch 11/250, Loss: 0.1457, Val Loss: 0.2370
# Epoch 12/250, Loss: 0.1385, Val Loss: 0.2376
# Epoch 13/250, Loss: 0.1348, Val Loss: 0.2393
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 7, 'optimizer_type': 'RMSProp', 'pooling_type': 'max'}
# Epoch 1/250, Loss: 0.4305, Val Loss: 0.3268
# Epoch 2/250, Loss: 0.2790, Val Loss: 0.3105
# Epoch 3/250, Loss: 0.2329, Val Loss: 0.2820
# Epoch 4/250, Loss: 0.2018, Val Loss: 0.2532
# Epoch 5/250, Loss: 0.1737, Val Loss: 0.2519
# Epoch 6/250, Loss: 0.1499, Val Loss: 0.2526
# Epoch 7/250, Loss: 0.1263, Val Loss: 0.2769
# Epoch 8/250, Loss: 0.1110, Val Loss: 0.2648
# Epoch 9/250, Loss: 0.0901, Val Loss: 0.3091
# Epoch 10/250, Loss: 0.0818, Val Loss: 0.3287
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 7, 'optimizer_type': 'RMSProp', 'pooling_type': 'avg'}
# Epoch 1/250, Loss: 0.4657, Val Loss: 0.3624
# Epoch 2/250, Loss: 0.3121, Val Loss: 0.3090
# Epoch 3/250, Loss: 0.2624, Val Loss: 0.2748
# Epoch 4/250, Loss: 0.2312, Val Loss: 0.2657
# Epoch 5/250, Loss: 0.2078, Val Loss: 0.2655
# Epoch 6/250, Loss: 0.1844, Val Loss: 0.2470
# Epoch 7/250, Loss: 0.1660, Val Loss: 0.2445
# Epoch 8/250, Loss: 0.1453, Val Loss: 0.2602
# Epoch 9/250, Loss: 0.1287, Val Loss: 0.2665
# Epoch 10/250, Loss: 0.1157, Val Loss: 0.2877
# Epoch 11/250, Loss: 0.0697, Val Loss: 0.2635
# Epoch 12/250, Loss: 0.0588, Val Loss: 0.2723
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 7, 'optimizer_type': 'Adam', 'pooling_type': 'max'}
# Epoch 1/250, Loss: 0.4243, Val Loss: 0.3525
# Epoch 2/250, Loss: 0.2807, Val Loss: 0.2862
# Epoch 3/250, Loss: 0.2347, Val Loss: 0.2917
# Epoch 4/250, Loss: 0.2013, Val Loss: 0.2528
# Epoch 5/250, Loss: 0.1741, Val Loss: 0.2644
# Epoch 6/250, Loss: 0.1500, Val Loss: 0.2623
# Epoch 7/250, Loss: 0.1295, Val Loss: 0.2831
# Epoch 8/250, Loss: 0.1106, Val Loss: 0.3207
# Epoch 9/250, Loss: 0.0965, Val Loss: 0.3116
# Early stopping triggered.
# Evaluating with params: {'epochs': 250, 'kernel_size': 7, 'optimizer_type': 'Adam', 'pooling_type': 'avg'}
# Epoch 1/250, Loss: 0.4699, Val Loss: 0.3511
# Epoch 2/250, Loss: 0.3072, Val Loss: 0.3108
# Epoch 3/250, Loss: 0.2608, Val Loss: 0.2799
# Epoch 4/250, Loss: 0.2291, Val Loss: 0.2662
# Epoch 5/250, Loss: 0.2032, Val Loss: 0.2522
# Epoch 6/250, Loss: 0.1831, Val Loss: 0.2604
# Epoch 7/250, Loss: 0.1644, Val Loss: 0.2638
# Epoch 8/250, Loss: 0.1461, Val Loss: 0.2680
# Epoch 9/250, Loss: 0.1284, Val Loss: 0.2440
# Epoch 10/250, Loss: 0.1128, Val Loss: 0.2738
# Epoch 11/250, Loss: 0.0680, Val Loss: 0.2647
# Epoch 12/250, Loss: 0.0568, Val Loss: 0.2748
# Epoch 13/250, Loss: 0.0516, Val Loss: 0.2785
# Early stopping triggered.
# Evaluating with params: {'epochs': 350, 'kernel_size': 3, 'optimizer_type': 'SGD', 'pooling_type': 'max'}
# Epoch 1/350, Loss: 0.5303, Val Loss: 0.3664
# Epoch 2/350, Loss: 0.3193, Val Loss: 0.3129
# Epoch 3/350, Loss: 0.2712, Val Loss: 0.2874
# Epoch 4/350, Loss: 0.2404, Val Loss: 0.2678
# Epoch 5/350, Loss: 0.2189, Val Loss: 0.2566
# Epoch 6/350, Loss: 0.1971, Val Loss: 0.2655
# Epoch 7/350, Loss: 0.1824, Val Loss: 0.2480
# Epoch 8/350, Loss: 0.1668, Val Loss: 0.2425
# Epoch 9/350, Loss: 0.1512, Val Loss: 0.2399
# Epoch 10/350, Loss: 0.1379, Val Loss: 0.2508
# Epoch 11/350, Loss: 0.0980, Val Loss: 0.2198
# Epoch 12/350, Loss: 0.0899, Val Loss: 0.2255
# Epoch 13/350, Loss: 0.0862, Val Loss: 0.2252
# Early stopping triggered.
# Evaluating with params: {'epochs': 350, 'kernel_size': 3, 'optimizer_type': 'SGD', 'pooling_type': 'avg'}
